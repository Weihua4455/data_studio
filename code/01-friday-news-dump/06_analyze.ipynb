# %%
import pandas as pd

import datetime
import time
import calendar

# %matplotlib inline

import matplotlib.pyplot as plt

import re

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option("display.max_colwidth", 1000)

# %%
df_bo_text = pd.read_csv("obama_press_release_w_text_all.csv")
df_dt_text = pd.read_csv("trump_w_content.csv")

# %%
df_bo = pd.read_csv("obama_weekly.csv")
df_dt = pd.read_csv("trump_weekly.csv")

# %%
df_dt.sort_values("Friday", ascending = False).head(10)
# Out:
#       datetime    Friday    Monday  Saturday    Sunday  Thursday   Tuesday  Wednesday  in_office_for
# 0   2017-01-22  0.666667       NaN       NaN  0.333333       NaN       NaN        NaN              2
# 54  2018-02-04  0.476190  0.142857       NaN  0.047619  0.047619  0.095238   0.190476            380
# 3   2017-02-12  0.470588       NaN  0.058824  0.117647  0.117647  0.176471   0.058824             23
# 44  2017-11-26  0.454545  0.090909  0.090909       NaN       NaN  0.181818   0.181818            310
# 49  2017-12-31  0.428571       NaN       NaN  0.142857  0.142857  0.142857   0.142857            345
# 26  2017-07-23  0.411765  0.117647       NaN       NaN  0.235294  0.058824   0.176471            184
# 58  2018-03-04  0.380952  0.047619  0.047619  0.095238  0.095238  0.238095   0.095238            408
# 57  2018-02-25  0.363636       NaN  0.045455  0.045455  0.181818  0.136364   0.227273            401
# ...

# %%
df_dt_text[df_dt_text["time"] == "Mar 2, 2018"]
# Out:
#                    issue         time                                              title                   type                                                url weekday                                            content
# 1026  LAND & AGRICULTURE  Mar 2, 2018  President Donald J. Trump Approves American Sa...  STATEMENTS & RELEASES  https://www.whitehouse.gov/briefings-statement...  Friday  ['Today, President Donald J. Trump declared th...
# 1027      FOREIGN POLICY  Mar 2, 2018  Statement from the Press Secretary Regarding R...  STATEMENTS & RELEASES  https://www.whitehouse.gov/briefings-statement...  Friday  ['The United States strongly condemns the brut...
# 1028           not found  Mar 2, 2018  Remarks by Vice President Pence at America Fir...                REMARKS  https://www.whitehouse.gov/briefings-statement...  Friday  [None, '4:39 P.M. EST', 'THE VICE PRESIDENT: W...
# ...

# %%
df_dt_text[df_dt_text["time"] == "Jan 21, 2017"]
# Out:
#                             issue          time                                                                    title             type                                                                                                             url   weekday  \
# 3165  NATIONAL SECURITY & DEFENSE  Jan 21, 2017  Remarks by President Trump and Vice President Pence at CIA Headquarters          REMARKS  https://www.whitehouse.gov/briefings-statements/remarks-president-trump-vice-president-pence-cia-headquarters/  Saturday
# 3166                    not found  Jan 21, 2017                                 Statement by Press Secretary Sean Spicer  PRESS BRIEFINGS                          https://www.whitehouse.gov/briefings-statements/statement-press-secretary-sean-spicer/  Saturday
#
# ...

# %%
df_dt_text[df_dt_text["time"] == "Nov 24, 2017"].count()
# Out:
# issue      5
# time       5
# title      5
# type       5
# url        5
# weekday    5
# content    5
# dtype: int64

# %%
df_bo[df_bo["in_office_for"] < 600].sort_values("Friday", ascending = False).head(10)
# Out:
#       datetime    Friday    Monday  Saturday  Sunday  Thursday   Tuesday  Wednesday  in_office_for
# 22  2009-06-21  0.437500  0.041667  0.041667     NaN  0.083333  0.208333   0.187500            152
# 3   2009-02-08  0.375000  0.062500       NaN     NaN  0.187500  0.250000   0.125000             19
# 2   2009-02-01  0.375000       NaN  0.062500     NaN  0.062500  0.125000   0.375000             12
# 38  2009-10-11  0.363636  0.227273       NaN     NaN  0.181818  0.136364   0.090909            264
# 82  2010-08-15  0.360000  0.160000       NaN     NaN  0.080000  0.240000   0.160000            572
# 29  2009-08-09  0.354839  0.129032       NaN     NaN  0.193548  0.129032   0.193548            201
# 85  2010-09-05  0.352941  0.294118  0.058824     NaN  0.058824  0.117647   0.117647            593
# 51  2010-01-10  0.350000  0.050000  0.100000     NaN  0.100000  0.150000   0.250000            355
# ...

# %%
df_bo_text[df_bo_text["time"] == "June 19, 2009"]
# Out:
#                 time                                                                                                                                                                    title                                                                                                                                          url weekday  \
# 11073  June 19, 2009                                                                                                             President Obama Signs Missouri Disaster Declaration, 6-19-09                           https://obamawhitehouse.archives.gov//the-press-office/president-obama-signs-missouri-disaster-declaration-6-19-09  Friday
# ...
